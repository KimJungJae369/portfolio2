# %%
/* Tech Stack Animation */
.tech-stack-container > div {
    opacity: 0;
    transform: translateY(50px);
    transition: opacity 0.8s ease-out, transform 0.8s cubic-bezier(0.22, 1, 0.36, 1);
}

.article-wrapper.in-view .tech-stack-container > div {
    opacity: 1;
    transform: translateY(0);
}

.article-wrapper.in-view .tech-stack-container > div:nth-child(1) { transition-delay: 0.2s; }
.article-wrapper.in-view .tech-stack-container > div:nth-child(2) { transition-delay: 0.4s; }
.article-wrapper.in-view .tech-stack-container > div:nth-child(3) { transition-delay: 0.6s; }
